# %% [markdown]
# <a href="https://colab.research.google.com/github/gousenahid8989-wq/chatbot/blob/main/simple_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
model=nn.Sequential(
    nn.Linear(2,4),
    nn.ReLU(),
    nn.Linear(4,1)
)

# %%
X=torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y=torch.tensor([[0.],[1.],[1.],[0.]])

# %% [markdown]
# LOSS FUNCTION AND OPTIMIZER
#
# 1)MSELoss:measures prediction error
# 2)Adam optimizer updates weights efficiently

# %%
loss_fn=nn.MSELoss()
opt=torch.optim.Adam(model.parameters(),lr=0.01)

# %%
for _ in range(1000):
  opt.zero_grad()
  loss=loss_fn(model(X),y)
  loss.backward()
  opt.step()

# %%
print(model(X))
# Out:
# tensor([[-2.2352e-07],
#         [ 1.0000e+00],
#         [ 1.0000e+00],
#         [-1.4901e-07]], grad_fn=<AddmmBackward0>)
